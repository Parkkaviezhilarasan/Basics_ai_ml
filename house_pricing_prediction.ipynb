# %%
import pandas as pd
house_prediction = pd.read_csv('/content/house_prediction.csv')
print(house_prediction.columns)
# Out:
# Index(['Size_sqft', 'Bedrooms', 'Age', 'Price'], dtype='object')

# %%
x=house_prediction[["Size_sqft","Bedrooms","Age"]]
y=house_prediction["Price"]
print(x.shape)
print(y.shape)
# Out:
# (7, 3)
# (7,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)

print("Weight=", model.coef_)
print("Bias=", model.intercept_)
# Out:
# Weight= [ 0.11676812  8.24571112 -0.73049253]
# Bias= 16.84006640841187

# %%
y_pred=model.predict(x)
print(list(y))
print(list(y_pred))
# Out:
# [150, 200, 170, 250, 160, 220, 280]
# [np.float64(146.44714997232987), np.float64(209.42446043165467), np.float64(167.6092971776425), np.float64(249.04814609850578), np.float64(159.58494742667406), np.float64(223.29275041505255), np.float64(274.5932484781405)]

# %%
new_pred=model.predict([[2750,3,5]])
print(new_pred)
# Out:
# [359.03707803]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import mean_squared_error

rmse_value=np.sqrt(mean_squared_error(y,y_pred))
print(rmse_value)
# Out:
# 4.602982255872528

# %%
from sklearn.metrics import r2_score

r2= r2_score(y,y_pred)
print(r2)
# Out:
# 0.9895344270489316
